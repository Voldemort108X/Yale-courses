# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
# %matplotlib inline
from sklearn import manifold 
from sklearn.decomposition import KernelPCA

# %%
data, color =sklearn.datasets.make_swiss_roll(n_samples=1500)
transformer = KernelPCA(n_components=7, kernel='linear', gamma=1/np.var(data))
data_transformed = transformer.fit_transform(data)
plt.scatter(data_transformed[:, 0], data_transformed[:, 1], c=color, lw=0)

# %%
data, color =sklearn.datasets.make_swiss_roll(n_samples=1500)
transformer = KernelPCA(n_components=7, kernel='poly', gamma=1/np.var(data))
data_transformed = transformer.fit_transform(data)
plt.scatter(data_transformed[:, 0], data_transformed[:, 1], c=color, lw=0)

# %%
data, color =sklearn.datasets.make_swiss_roll(n_samples=1500)
transformer = KernelPCA(n_components=7, kernel='rbf', gamma=1/np.var(data))
data_transformed = transformer.fit_transform(data)
plt.scatter(data_transformed[:, 0], data_transformed[:, 1], c=color, lw=0)

# %%
data, color =sklearn.datasets.make_swiss_roll(n_samples=1500)
transformer = KernelPCA(n_components=7, kernel='sigmoid', gamma=1/np.var(data))
data_transformed = transformer.fit_transform(data)
plt.scatter(data_transformed[:, 0], data_transformed[:, 1], c=color, lw=0)

# %%
data, color =sklearn.datasets.make_swiss_roll(n_samples=1500)
transformer = KernelPCA(n_components=7, kernel='cosine', gamma=1/np.var(data))
data_transformed = transformer.fit_transform(data)
plt.scatter(data_transformed[:, 0], data_transformed[:, 1], c=color, lw=0)
